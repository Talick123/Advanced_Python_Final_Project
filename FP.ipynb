# %% [markdown]
# ## --- 1 Plane with camera position

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])
camera_target = np.array([0.736, -0.585, 338])

# Plot the reference plane
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color='gray', alpha=0.5)

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos[2], color='red', label='Camera Position')

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
plt.title('Reference Plane and Camera Position')

# Show plot
plt.show()

# %% [markdown]
# ## --- 2 Same as 1 (?)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])
camera_target = np.array([0.736, -0.585, 338])

# Plot the reference plane with specified color
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color=(0.5, 0.5, 0.5), alpha=0.5)  # Set color to (0.5, 0.5, 0.5)

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos[2], color='red', label='Camera Position')

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
plt.title('Reference Plane and Camera Position')

# Show plot
plt.show()

# %% [markdown]
# ## --- 3 Plane with camera and light position

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])
camera_target = np.array([0.736, -0.585, 338])

# Define the light source vector
light_vector = np.array([0.563, 0.139, 0.815])

# Calculate the light source position
light_pos = camera_pos + light_vector  # Assuming light direction is relative to camera position

# Plot the reference plane
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color='gray', alpha=0.5)  # Reference plane

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos[2], color='red', label='Camera Position')

# Add a visual representation of the light source
ax.scatter(light_pos[0], light_pos[1], light_pos[2], color='yellow', s=100, label='Light Source')  # Yellow sphere representing the light source

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
plt.title('Reference Plane with Camera and Light Source')

# Add a legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ## --- 4 Plane with cube

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])
camera_target = np.array([0.736, -0.585, 338])

# Define the position of the cube and calculate its vertices
cube_center = np.array([1.58, 0.08, 0.5])  # Center of the cube
cube_size = 1.0  # Size of the cube

# Calculate the vertices of the cube
cube_vertices = np.array([
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2]
])

# Define the edges of the cube
cube_edges = [
    [cube_vertices[0], cube_vertices[1], cube_vertices[2], cube_vertices[3], cube_vertices[0]],
    [cube_vertices[4], cube_vertices[5], cube_vertices[6], cube_vertices[7], cube_vertices[4]],
    [cube_vertices[0], cube_vertices[4]],
    [cube_vertices[1], cube_vertices[5]],
    [cube_vertices[2], cube_vertices[6]],
    [cube_vertices[3], cube_vertices[7]]
]

# Plot the reference plane
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color='gray', alpha=0.5)  # Reference plane

# Plot the cube edges
for edge in cube_edges:
    # noga
    if (len(edge)) > 2:
        ax.plot3D(*zip(*edge), color='cyan')
    else:
        ax.plot3D(*zip(*edge), color='blue')

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos[2], color='red', label='Camera Position')

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
plt.title('Reference Plane with Camera and Cube')

# Add a legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ## --- 5 Same as 4 but with ratio so the cube look like a cube

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])
camera_target = np.array([0.736, -0.585, 338])

# Define the position of the cube and calculate its vertices
cube_center = np.array([1.58, 0.08, 0.5])  # Center of the cube
cube_size = 1.0  # Size of the cube

# Calculate the vertices of the cube
cube_vertices = np.array([
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2]
])

# Define the edges of the cube
cube_edges = [
    [cube_vertices[0], cube_vertices[1], cube_vertices[2], cube_vertices[3], cube_vertices[0]],
    [cube_vertices[4], cube_vertices[5], cube_vertices[6], cube_vertices[7], cube_vertices[4]],
    [cube_vertices[0], cube_vertices[4]],
    [cube_vertices[1], cube_vertices[5]],
    [cube_vertices[2], cube_vertices[6]],
    [cube_vertices[3], cube_vertices[7]]
]

# Plot the reference plane
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color='gray', alpha=0.5)  # Reference plane

# Plot the cube edges
for edge in cube_edges:
    ax.plot3D(*zip(*edge), color='blue')

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos[2], color='red', label='Camera Position')

# Set aspect ratio and axis limits to make the cube look like a cube
max_range = np.array([cube_vertices[:,0].max()-cube_vertices[:,0].min(), cube_vertices[:,1].max()-cube_vertices[:,1].min(), cube_vertices[:,2].max()-cube_vertices[:,2].min()]).max()
ax.set_xlim(cube_center[0] - max_range/2, cube_center[0] + max_range/2)
ax.set_ylim(cube_center[1] - max_range/2, cube_center[1] + max_range/2)
ax.set_zlim(cube_center[2] - max_range/2, cube_center[2] + max_range/2)
ax.set_box_aspect([1,1,1])  # Set aspect ratio to make the cube look like a cube

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
plt.title('Reference Plane with Camera and Cube')

# Add a legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ## --- 6 Cube with angle (no ratio)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define rotation function
def rotation_matrix(axis, theta):
    """
    Return the rotation matrix associated with counterclockwise rotation about
    the given axis by theta radians.
    """
    axis = np.asarray(axis)
    axis = axis / np.sqrt(np.dot(axis, axis))
    a = np.cos(theta / 2.0)
    b, c, d = -axis * np.sin(theta / 2.0)
    aa, bb, cc, dd = a * a, b * b, c * c, d * d
    bc, ad, ac, ab, bd, cd = b * c, a * d, a * c, a * b, b * d, c * d
    return np.array([[aa + bb - cc - dd, 2 * (bc + ad), 2 * (bd - ac)],
                     [2 * (bc - ad), aa + cc - bb - dd, 2 * (cd + ab)],
                     [2 * (bd + ac), 2 * (cd - ab), aa + dd - bb - cc]])

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])
camera_target = np.array([0.736, -0.585, 338])

# Define the position of the cube and calculate its vertices
cube_center = np.array([1.58, 0.08, 0.5])  # Center of the cube
cube_size = 1.0  # Size of the cube

# Calculate the vertices of the cube
cube_vertices = np.array([
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2]
])

# Define the axis of rotation and rotation angle
rotation_axis = np.array([0, 0, 1])  # Axis passing through z=-57.7
rotation_angle = np.pi / 4  # Rotate by 45 degrees

# Rotate the cube around the axis passing through z=-57.7
for i in range(len(cube_vertices)):
    cube_vertices[i] -= cube_center
    cube_vertices[i] = np.dot(rotation_matrix(rotation_axis, rotation_angle), cube_vertices[i]) + cube_center

# Define the edges of the cube
cube_edges = [
    [cube_vertices[0], cube_vertices[1], cube_vertices[2], cube_vertices[3], cube_vertices[0]],
    [cube_vertices[4], cube_vertices[5], cube_vertices[6], cube_vertices[7], cube_vertices[4]],
    [cube_vertices[0], cube_vertices[4]],
    [cube_vertices[1], cube_vertices[5]],
    [cube_vertices[2], cube_vertices[6]],
    [cube_vertices[3], cube_vertices[7]]
]

# Plot the reference plane
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color='gray', alpha=0.5)  # Reference plane

# Plot the cube edges
for edge in cube_edges:
    ax.plot3D(*zip(*edge), color='blue')

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos[2], color='red', label='Camera Position')

# Set aspect ratio and axis limits to make the cube look like a cube
max_range = np.array([cube_vertices[:,0].max()-cube_vertices[:,0].min(), cube_vertices[:,1].max()-cube_vertices[:,1].min(), cube_vertices[:,2].max()-cube_vertices[:,2].min()]).max()
ax.set_xlim(cube_center[0] - max_range, cube_center[0] + max_range)
ax.set_ylim(cube_center[1] - max_range, cube_center[1] + max_range)
ax.set_zlim(cube_center[2] - max_range, cube_center[2] + max_range)
ax.set_box_aspect([2,2,2])  # Set aspect ratio to make the cube look like a cube

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# ## --- 7 same as 4?

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define rotation function - NOGA: function not in use?
def rotation_matrix(axis, theta):
    axis = np.asarray(axis)
    axis = axis / np.sqrt(np.dot(axis, axis))
    a = np.cos(theta / 2.0)
    b, c, d = -axis * np.sin(theta / 2.0)
    aa, bb, cc, dd = a * a, b * b, c * c, d * d
    bc, ad, ac, ab, bd, cd = b * c, a * d, a * c, a * b, b * d, c * d
    return np.array([[aa + bb - cc - dd, 2 * (bc + ad), 2 * (bd - ac)],
                     [2 * (bc - ad), aa + cc - bb - dd, 2 * (cd + ab)],
                     [2 * (bd + ac), 2 * (cd - ab), aa + dd - bb - cc]])

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])

# Define the position of the cube and calculate its vertices
cube_center = np.array([1.58, 0.08, 0.5])  # Center of the cube
cube_size = 1.0  # Size of the cube

# Calculate the vertices of the cube
cube_vertices = np.array([
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2]
])

# Define the edges of the cube
cube_edges = [
    [cube_vertices[0], cube_vertices[1], cube_vertices[2], cube_vertices[3], cube_vertices[0]],
    [cube_vertices[4], cube_vertices[5], cube_vertices[6], cube_vertices[7], cube_vertices[4]],
    [cube_vertices[0], cube_vertices[4]],
    [cube_vertices[1], cube_vertices[5]],
    [cube_vertices[2], cube_vertices[6]],
    [cube_vertices[3], cube_vertices[7]]
]

# Plot the reference plane
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color='gray', alpha=0.5)  # Reference plane

# Plot the cube edges
for edge in cube_edges:
    ax.plot3D(*zip(*edge), color=(0.6, 0.6, 0.6))

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos[2], color='red', label='Camera Position')

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
plt.title('Reference Plane with Camera and Cube')

# Add a legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ## --- 8 ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Define rotation function
def rotation_matrix(axis, theta):
    axis = np.asarray(axis)
    axis = axis / np.sqrt(np.dot(axis, axis))
    a = np.cos(theta / 2.0)
    b, c, d = -axis * np.sin(theta / 2.0)
    aa, bb, cc, dd = a * a, b * b, c * c, d * d
    bc, ad, ac, ab, bd, cd = b * c, a * d, a * c, a * b, b * d, c * d
    return np.array([[aa + bb - cc - dd, 2 * (bc + ad), 2 * (bd - ac)],
                     [2 * (bc - ad), aa + cc - bb - dd, 2 * (cd + ab)],
                     [2 * (bd + ac), 2 * (cd - ab), aa + dd - bb - cc]])

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])

# Define the position of the cube and calculate its vertices
cube_center = np.array([1.58, 0.08, 0.5])  # Center of the cube
cube_size = 1.0  # Size of the cube

# Calculate the vertices of the cube
cube_vertices = np.array([
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] - cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] - cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] + cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2],
    [cube_center[0] - cube_size / 2, cube_center[1] + cube_size / 2, cube_center[2] + cube_size / 2]
])

# Define the faces of the cube
cube_faces = [
    [cube_vertices[0], cube_vertices[1], cube_vertices[2], cube_vertices[3]],  # Front face
    [cube_vertices[4], cube_vertices[5], cube_vertices[6], cube_vertices[7]],  # Back face
    [cube_vertices[0], cube_vertices[1], cube_vertices[5], cube_vertices[4]],  # Bottom face
    [cube_vertices[2], cube_vertices[3], cube_vertices[7], cube_vertices[6]],  # Top face
    [cube_vertices[0], cube_vertices[3], cube_vertices[7], cube_vertices[4]],  # Left face
    [cube_vertices[1], cube_vertices[2], cube_vertices[6], cube_vertices[5]]   # Right face
]

# Plot the reference plane
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color='gray', alpha=0.5)  # Reference plane

# Plot the cube faces
for face in cube_faces:
    # ax.add_collection3d(Poly3DCollection([face], color=(0.6, 0.6, 0.6)))
    ax.add_collection3d(Poly3DCollection([face], color=(0.6, 0.8, 0.6))) # NOGA- kind of green
    

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos)

# %% [markdown]
# ## --- 9 ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Define rotation function
def rotation_matrix(axis, theta):
    axis = np.asarray(axis)
    axis = axis / np.sqrt(np.dot(axis, axis))
    a = np.cos(theta / 2.0)
    b, c, d = -axis * np.sin(theta / 2.0)
    aa, bb, cc, dd = a * a, b * b, c * c, d * d
    bc, ad, ac, ab, bd, cd = b * c, a * d, a * c, a * b, b * d, c * d
    return np.array([[aa + bb - cc - dd, 2 * (bc + ad), 2 * (bd - ac)],
                     [2 * (bc - ad), aa + cc - bb - dd, 2 * (cd + ab)],
                     [2 * (bd + ac), 2 * (cd - ab), aa + dd - bb - cc]])

# Define the reference plane
plane_x = np.linspace(-5, 5, 100)
plane_y = np.linspace(-5, 5, 100)
plane_x, plane_y = np.meshgrid(plane_x, plane_y)
plane_z = np.zeros_like(plane_x)

# Define camera position
camera_pos = np.array([0.0, 0.0, 0.0])

# Define the position of cube1 and calculate its vertices
cube1_center = np.array([1.58, 0.08, 0.5])  # Center of cube1
cube1_size = 1.0  # Size of cube1

# Calculate the vertices of cube1
cube1_vertices = np.array([
    [cube1_center[0] - cube1_size / 2, cube1_center[1] - cube1_size / 2, cube1_center[2] - cube1_size / 2],
    [cube1_center[0] + cube1_size / 2, cube1_center[1] - cube1_size / 2, cube1_center[2] - cube1_size / 2],
    [cube1_center[0] + cube1_size / 2, cube1_center[1] + cube1_size / 2, cube1_center[2] - cube1_size / 2],
    [cube1_center[0] - cube1_size / 2, cube1_center[1] + cube1_size / 2, cube1_center[2] - cube1_size / 2],
    [cube1_center[0] - cube1_size / 2, cube1_center[1] - cube1_size / 2, cube1_center[2] + cube1_size / 2],
    [cube1_center[0] + cube1_size / 2, cube1_center[1] - cube1_size / 2, cube1_center[2] + cube1_size / 2],
    [cube1_center[0] + cube1_size / 2, cube1_center[1] + cube1_size / 2, cube1_center[2] + cube1_size / 2],
    [cube1_center[0] - cube1_size / 2, cube1_center[1] + cube1_size / 2, cube1_center[2] + cube1_size / 2]
])

# Define the faces of cube1
cube1_faces = [
    [cube1_vertices[0], cube1_vertices[1], cube1_vertices[2], cube1_vertices[3]],  # Front face
    [cube1_vertices[4], cube1_vertices[5], cube1_vertices[6], cube1_vertices[7]],  # Back face
    [cube1_vertices[0], cube1_vertices[1], cube1_vertices[5], cube1_vertices[4]],  # Bottom face
    [cube1_vertices[2], cube1_vertices[3], cube1_vertices[7], cube1_vertices[6]],  # Top face
    [cube1_vertices[0], cube1_vertices[3], cube1_vertices[7], cube1_vertices[4]],  # Left face
    [cube1_vertices[1], cube1_vertices[2], cube1_vertices[6], cube1_vertices[5]]   # Right face
]

# Define the position of cube2 and calculate its vertices
cube2_center = np.array([0.58, -1.2, 0.5])  # Center of cube2
cube2_size = 1.0  # Size of cube2

# Calculate the vertices of cube2
cube2_vertices = np.array([
    [cube2_center[0] - cube2_size / 2, cube2_center[1] - cube2_size / 2, cube2_center[2] - cube2_size / 2],
    [cube2_center[0] + cube2_size / 2, cube2_center[1] - cube2_size / 2, cube2_center[2] - cube2_size / 2],
    [cube2_center[0] + cube2_size / 2, cube2_center[1] + cube2_size / 2, cube2_center[2] - cube2_size / 2],
    [cube2_center[0] - cube2_size / 2, cube2_center[1] + cube2_size / 2, cube2_center[2] - cube2_size / 2],
    [cube2_center[0] - cube2_size / 2, cube2_center[1] - cube2_size / 2, cube2_center[2] + cube2_size / 2],
    [cube2_center[0] + cube2_size / 2, cube2_center[1] - cube2_size / 2, cube2_center[2] + cube2_size / 2],
    [cube2_center[0] + cube2_size / 2, cube2_center[1] + cube2_size / 2, cube2_center[2] + cube2_size / 2],
    [cube2_center[0] - cube2_size / 2, cube2_center[1] + cube2_size / 2, cube2_center[2] + cube2_size / 2]
])

# Rotate cube2 around z-axis
rotation_angle = -55.9 * np.pi / 180  # Convert to radians
for i in range(len(cube2_vertices)):
    cube2_vertices[i] -= cube2_center
    cube2_vertices[i] = np.dot(rotation_matrix([0, 0, 1], rotation_angle), cube2_vertices[i]) + cube2_center

cube2_faces = [
    [cube2_vertices[0], cube2_vertices[1], cube2_vertices[2], cube2_vertices[3]],  # Front face
    [cube2_vertices[4], cube2_vertices[5], cube2_vertices[6], cube2_vertices[7]],  # Back face
    [cube2_vertices[0], cube2_vertices[1], cube2_vertices[5], cube2_vertices[4]],  # Bottom face
    [cube2_vertices[2], cube2_vertices[3], cube2_vertices[7], cube2_vertices[6]],  # Top face
    [cube2_vertices[0], cube2_vertices[3], cube2_vertices[7], cube2_vertices[4]],  # Left face
    [cube2_vertices[1], cube2_vertices[2], cube2_vertices[6], cube2_vertices[5]]   # Right face
]

# Plot the reference plane
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(plane_x, plane_y, plane_z, color=(0.7, 0.7, 0.7), alpha=0.5)  # Reference plane

# Plot cube1
for face in cube1_faces:
    ax.add_collection3d(Poly3DCollection([face], color=(0.6, 0.6, 0.6)))

# Plot cube2
for face in cube2_faces:
    ax.add_collection3d(Poly3DCollection([face], color=(0.75, 0.5, 0.2)))

# Plot the camera position
ax.scatter(camera_pos[0], camera_pos[1], camera_pos[2], color='red', label='Camera Position')

# # NOGA - tried to add this for the aspect ratio
# # Set aspect ratio and axis limits to make the cube look like a cube
# max_range = np.array([cube_vertices[:,0].max()-cube_vertices[:,0].min(), cube_vertices[:,1].max()-cube_vertices[:,1].min(), cube_vertices[:,2].max()-cube_vertices[:,2].min()]).max()
# ax.set_xlim(cube_center[0] - max_range, cube_center[0] + max_range)
# ax.set_ylim(cube_center[1] - max_range, cube_center[1] + max_range)
# ax.set_zlim(cube_center[2] - max_range, cube_center[2] + max_range)
# ax.set_box_aspect([2,2,2])  # Set aspect ratio to make the cube look like a cube

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set plot title
plt.title('Reference Plane with Camera and Cubes')

# Add a legend
plt.legend()

# Show plot
plt.show()
